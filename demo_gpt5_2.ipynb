# %%
import warnings
from tqdm import TqdmWarning
warnings.filterwarnings("ignore", category=TqdmWarning)

from chat import ChatSession
session = ChatSession("openai_latest")
# Out:
# Setting model provider to: openai_latest
# Chat session with assistant initialized using model: OpenAI GPT-5.2 2025-12-11 Snapshot

# %%
print(session.start_chat("What is a microstrip antenna?"))
# Out:
# Found text with semantic search. Proceeding to reranking...
# A **microstrip antenna** (often called a **patch antenna**) is a planar antenna made from a **metallic patch (radiating element)** printed on one side of a **thin dielectric substrate**, with a **conducting ground plane** on the other side. The patch acts essentially as a **resonator**, with its dimensions chosen to be on the order of (multiples of) the **effective wavelength in the substrate**. Common patch shapes include **rectangular, circular, and triangular**, and the antenna is typically fed by a **coaxial probe**, a **microstrip line**, or by **aperture coupling** through a slot in the ground plane.
#
# Source: *SYSC 4607 – Wireless Communications (2e)*, Section 9.2.3 “Microstrip Antennas,” p. 228.

# %%
print(session.continue_chat("What is a horn antenna? How does it differ from a microstrip antenna?"))
# Out:
# Found text with semantic search. Proceeding to reranking...
# ### Horn antenna (what it is)
# A **horn antenna** is an **aperture antenna** formed by flaring the end of a waveguide so that electromagnetic fields across the **open aperture** radiate efficiently into free space. In this view, the **electric and magnetic fields across the horn’s aperture** act as the radiating sources (an “aperture-field source”).
# Source: *Fundamentals of Applied Electromagnetics (6th ed.)*, p. 419 (discussion of horn as an aperture-field source, Fig. 9‑2).
#
# ### How it differs from a microstrip (patch) antenna
# A **microstrip (patch) antenna** is a **planar printed antenna**: a **metal patch** on one side of a **thin dielectric substrate** with a **ground plane** on the other side; the patch behaves essentially as a **resonator** and is fed by a coaxial probe, microstrip line, or coupling scheme.
# Source: *SYSC 4607 – Wireless Communications (2e)*, p. 228 (Section 9.2.3).
#
# Key differences (conceptual and physical):
# - **Radiation mechanism**
#   - **Horn:** radiates from **aperture fields** at an open mouth (aperture-source model). (FAE 6e, p. 419)
#   - **Microstrip:** radiates primarily from **fringing fields** around a resonant printed patch (resonator/printed structure). (SYSC 4607, p. 228)
# - **Structure / form factor**
#   - **Horn:** a **3D flared waveguide** (bulkier).
#   - **Microstrip:** **low-profile planar** structure (printed on a substrate). (SYSC 4607, p. 228)
# - **Typical use tendencies (general)**
#   - **Horn:** often used at **microwave/mmWave** as a feed or for **higher directivity**.
#   - **Microstrip:** widely used where **compact, conformal, PCB-integrated** antennas are needed.
#
# If you want, I can also summarize typical bandwidth/gain and polarization characteristics for each (with textbook citations), but I’d need to pull the relevant pages for horn antenna performance details.

# %%
print(session.clear_chat())
# Out:
# Chat session cleared.
# None
